# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df = pd.read_csv(r'./Hospital General Information.csv',sep=";", encoding='cp1252')
#df.drop(['Provider ID', ''], axis=1)
import csv
with open('Hospital General Information.csv', 'r', newline='') as file:
    csv_reader = csv.reader(file, delimiter=',', quotechar='"')
    df = pd.read_csv(file)

# %%
df = df[[
"Hospital Type","Hospital Ownership","Emergency Services","Hospital overall rating","Mortality national comparison",
"Safety of care national comparison","Readmission national comparison","Patient experience national comparison",
"Effectiveness of care national comparison","Timeliness of care national comparison","Efficient use of medical imaging national comparison"]]
df
# Out:
#              Hospital Type                           Hospital Ownership  \
# 0     Acute Care Hospitals  Government - Hospital District or Authority
# 1     Acute Care Hospitals  Government - Hospital District or Authority
# 2     Acute Care Hospitals  Government - Hospital District or Authority
# 3     Acute Care Hospitals               Voluntary non-profit - Private
# 4     Acute Care Hospitals                                  Proprietary
# ...                    ...                                          ...
# 4807  Acute Care Hospitals                                  Proprietary
# 4808  Acute Care Hospitals  Government - Hospital District or Authority
# 4809  Acute Care Hospitals                           Government - Local
# 4810  Acute Care Hospitals               Voluntary non-profit - Private
# 4811  Acute Care Hospitals                                  Proprietary
#
#      Emergency Services Hospital overall rating Mortality national comparison  \
# ...

# %%
df.describe()
# Out:
#                Hospital Type              Hospital Ownership  \
# count                   4812                            4812
# unique                     3                              10
# top     Acute Care Hospitals  Voluntary non-profit - Private
# freq                    3369                            2052
#
#        Emergency Services Hospital overall rating  \
# count                4812                    4812
# unique                  2                       6
# top                   Yes                       3
# freq                 4497                    1761
#
#        Mortality national comparison Safety of care national comparison  \
# count                           4812                               4812
# unique                             4                                  4
# top     Same as the national average                      Not Available
# freq                            2719                               2168
#
# ...

# %% [markdown]
# #Visualizing data

# %%
for i, item in enumerate(df):
    plt.figure(figsize = (20, 6))
    sns.countplot(x = item, data = df)
    xt = plt.xticks(rotation=45)
    plt.xlabel(item)
    plt.ylabel('Count')
    plt.title(item)
